# %%
from cosine_lr import CosineLRScheduler
import torch

# %%
import matplotlib.pyplot as plt

def scheduler():
    model = torch.nn.Linear(1, 1) ## 適当なモデル
    optimizer = torch.optim.Adam(model.parameters(), lr=1)
    scheduler = CosineLRScheduler(optimizer, t_initial=200, lr_min=1e-2, 
                                  warmup_t=20, warmup_lr_init=1e-1, warmup_prefix=True)

    lrs = []
    for i in range(200):
        lrs.append(scheduler._get_lr(i))
    plt.plot(lrs)
    plt.show()

# %%
scheduler()

# %%
scheduler = CosineLRScheduler(optimizer, t_initial=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 scheduler = CosineLRScheduler()
#
# TypeError: __init__() missing 2 required positional arguments: 'optimizer' and 't_initial'

# %%
if scheduler == "CosineAnnealingLR":
    scheduler = lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=T_max, eta_min=eta_min
    )
elif scheduler == "CosineAnnealingWithWarmUp":
    scheduler = CosineLRScheduler(
        optimizer,
        t_initial=500,
        lr_min=eta_min,
        warmup_t=20,
        warmup_lr_init=eta_min,
        warmup_prefix=True,
    )
